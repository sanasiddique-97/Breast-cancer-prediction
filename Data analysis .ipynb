# %%
import pandas as pd 
import numpy as np

# %%
validation_result_X = pd.read_csv("validation-result_X.csv", encoding="ISO-8859-1")

# %%
validation_result_X
# Out:
#                                           AbsolutePath  \
# 0    D:/cancercases\duplicate\Yeni klasör (119)\FIL...
# 1    D:/cancercases\duplicate\Yeni klasör (119)\FIL...
# 2    D:/cancercases\duplicate\Yeni klasör (119)\FIL...
# 3    D:/cancercases\duplicate\Yeni klasör (120)\FIL...
# 4    D:/cancercases\TANILI\Yeni klasör (24)\FILES\F...
# ..                                                 ...
# 317  D:/cancercases\TANI GÖRÜNTÜSÜZLER\Yeni klasör ...
# 318  D:/cancercases\TANI GÖRÜNTÜSÜZLER\Yeni klasör ...
# 319  D:/cancercases\TANI GÖRÜNTÜSÜZLER\Yeni klasör ...
# 320  D:/cancercases\TANI GÖRÜNTÜSÜZLER\Yeni klasör ...
# 321  D:/cancercases\TANI GÖRÜNTÜSÜZLER\Yeni klasör ...
#
#                                    RelativePath InputFileName  StudyDate  \
# 0    duplicate\Yeni klasör (119)\FILES\FILE0000      FILE0000   20150620
# 1    duplicate\Yeni klasör (119)\FILES\FILE0004      FILE0004   20190628
# 2    duplicate\Yeni klasör (119)\FILES\FILE0008      FILE0008   20170622
# ...

# %%
validation_result_X.columns
# Out:
# Index(['AbsolutePath', 'RelativePath', 'InputFileName', 'StudyDate',
#        'StudyTime', 'PatientID', 'PatientBirthDate', 'PatientSex',
#        'PatientAge', 'LCC', 'LMLO', 'RCC', 'RMLO', 'Density', 'Note'],
#       dtype='object')

# %%
print(validation_result_X.columns)
print(validation_result_X["AbsolutePath"].duplicated().sum())
print(validation_result_X["RelativePath"].duplicated().sum())
print(validation_result_X["PatientID"].duplicated().sum())
# Out:
# Index(['AbsolutePath', 'RelativePath', 'InputFileName', 'StudyDate',
#        'StudyTime', 'PatientID', 'PatientBirthDate', 'PatientSex',
#        'PatientAge', 'LCC', 'LMLO', 'RCC', 'RMLO', 'Density', 'Note'],
#       dtype='object')
# 0
# 0
# 177

# %%
validation_result_raw = pd.read_csv("validation-result.csv.raw.csv", encoding="ISO-8859-1")
validation_result_raw
# Out:
#                                            AbsolutePath  \
# 0     D:/cancercases\duplicate\Yeni klasör (119)\FIL...
# 1     D:/cancercases\duplicate\Yeni klasör (119)\FIL...
# 2     D:/cancercases\duplicate\Yeni klasör (119)\FIL...
# 3     D:/cancercases\duplicate\Yeni klasör (119)\FIL...
# 4     D:/cancercases\duplicate\Yeni klasör (119)\FIL...
# ...                                                 ...
# 1174  D:/cancercases\TANILI\Yeni klasör (9)\FILES\FI...
# 1175  D:/cancercases\TANILI\Yeni klasör (9)\FILES\FI...
# 1176  D:/cancercases\TANILI\Yeni klasör (9)\FILES\FI...
# 1177  D:/cancercases\TANILI\Yeni klasör (9)\FILES\FI...
# 1178  D:/cancercases\TANILI\Yeni klasör (9)\FILES\FI...
#
#                                     RelativePath InputFileName  StudyDate  \
# 0     duplicate\Yeni klasör (119)\FILES\FILE0000      FILE0000   20150620
# 1     duplicate\Yeni klasör (119)\FILES\FILE0001      FILE0001   20150620
# ...

# %%
print(validation_result_raw.columns)
print(validation_result_raw["AbsolutePath"].duplicated().sum())
print(validation_result_raw["RelativePath"].duplicated().sum())
print(validation_result_raw["PatientID"].duplicated().sum())
# Out:
# Index(['AbsolutePath', 'RelativePath', 'InputFileName', 'StudyDate',
#        'StudyTime', 'PatientID', 'PatientBirthDate', 'PatientSex',
#        'PatientAge', 'ViewName', 'Score', 'Note'],
#       dtype='object')
# 0
# 0
# 1034
